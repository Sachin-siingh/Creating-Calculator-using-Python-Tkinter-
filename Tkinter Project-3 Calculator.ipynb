# %%
from tkinter import *

def click(event):
    global var1
    text = event.widget.cget("text")
    if text == "=":
        if var1.get().isdigit():
            value = int(var1.get())
        else:
            try:
                value = eval(screen.get())

            except Exception as e:
                print(e)
                value = "Error"


        var1.set(value)
        screen.update()

    elif text == "C":
        var1.set("")
        screen.update()

    else:
        var1.set(var1.get() + text)
        screen.update()

root=Tk()
root.geometry("500x700")
root.minsize(500,700)
root.maxsize(500,700)
root.configure(background="black")
root.title("Calculator created by sachin")
root.wm_iconbitmap("Gchro.ico")

var1 =StringVar()
var1.set("")

screen =Entry(root,text=var1, font="lucida 32 bold",relief =FLAT,bg="black",fg="white")
screen.pack(padx=10,pady=10,fill=X)

f1=Frame(root,bg="black")
b1=Button(f1,text="=",height=1,width=4,padx=20,pady=20,font="lucida 20 bold",bg="black",fg="white")
b1.pack(side=LEFT,padx=15,pady=5)
b1.bind("<Button-1>",click)

b2=Button(f1,text="00",height=1,width=4,padx=20,pady=20,font="lucida 20 bold",bg="black",fg="white")
b2.pack(side=LEFT,padx=15,pady=5)
b2.bind("<Button-1>",click)

b3=Button(f1,text="%",height=1,width=4,padx=20,pady=20,font="lucida 20 bold",bg="black",fg="white")
b3.pack(side=LEFT,padx=15,pady=5)
b3.bind("<Button-1>",click)

f1.pack(fill=X)

f1=Frame(root,bg="black")
b1=Button(f1,text="9",height=1,width=4,padx=20,pady=20,font="lucida 20 bold",bg="black",fg="white")
b1.pack(side=LEFT,padx=15,pady=5)
b1.bind("<Button-1>",click)

b2=Button(f1,text="8",height=1,width=4,padx=20,pady=20,font="lucida 20 bold",bg="black",fg="white")
b2.pack(side=LEFT,padx=15,pady=5)
b2.bind("<Button-1>",click)

b3=Button(f1,text="7",height=1,width=4,padx=20,pady=20,font="lucida 20 bold",bg="black",fg="white")
b3.pack(side=LEFT,padx=15,pady=5)
b3.bind("<Button-1>",click)

f1.pack(fill=X)

f1=Frame(root,bg="black")
b1=Button(f1,text="6",height=1,width=4,padx=20,pady=20,font="lucida 20 bold",bg="black",fg="white")
b1.pack(side=LEFT,padx=15,pady=5)
b1.bind("<Button-1>",click)

b2=Button(f1,text="5",height=1,width=4,padx=20,pady=20,font="lucida 20 bold",bg="black",fg="white")
b2.pack(side=LEFT,padx=15,pady=5)
b2.bind("<Button-1>",click)

b3=Button(f1,text="4",height=1,width=4,padx=20,pady=20,font="lucida 20 bold",bg="black",fg="white")
b3.pack(side=LEFT,padx=15,pady=5)
b3.bind("<Button-1>",click)

f1.pack(fill=X)

f1=Frame(root,bg="black")
b1=Button(f1,text="3",height=1,width=4,padx=20,pady=20,font="lucida 20 bold",bg="black",fg="white")
b1.pack(side=LEFT,padx=15,pady=5)
b1.bind("<Button-1>",click)

b2=Button(f1,text="2",height=1,width=4,padx=20,pady=20,font="lucida 20 bold",bg="black",fg="white")
b2.pack(side=LEFT,padx=15,pady=5)
b2.bind("<Button-1>",click)

b3=Button(f1,text="1",height=1,width=4,padx=20,pady=20,font="lucida 20 bold",bg="black",fg="white")
b3.pack(side=LEFT,padx=15,pady=5)
b3.bind("<Button-1>",click)

f1.pack(fill=X)

f1=Frame(root,bg="black")
b1=Button(f1,text="0",height=1,width=4,padx=20,pady=20,font="lucida 20 bold",bg="black",fg="white")
b1.pack(side=LEFT,padx=15,pady=5)
b1.bind("<Button-1>",click)

b2=Button(f1,text="C",height=1,width=4,padx=20,pady=20,font="lucida 20 bold",bg="black",fg="white")
b2.pack(side=LEFT,padx=15,pady=5)
b2.bind("<Button-1>",click)

b3=Button(f1,text="-",height=1,width=4,padx=20,pady=20,font="lucida 20 bold",bg="black",fg="white")
b3.pack(side=LEFT,padx=15,pady=5)
b3.bind("<Button-1>",click)

f1.pack(fill=X)

f1=Frame(root,bg="black")
b1=Button(f1,text="+",height=1,width=4,padx=20,pady=20,font="lucida 20 bold",bg="black",fg="white")
b1.pack(side=LEFT,padx=15,pady=5)
b1.bind("<Button-1>",click)

b2=Button(f1,text="*",height=1,width=4,padx=20,pady=20,font="lucida 20 bold",bg="black",fg="white")
b2.pack(side=LEFT,padx=15,pady=5)
b2.bind("<Button-1>",click)

b3=Button(f1,text="/",height=1,width=4,padx=20,pady=20,font="lucida 20 bold",bg="black",fg="white")
b3.pack(side=LEFT,padx=15,pady=5)
b3.bind("<Button-1>",click)

f1.pack(fill=X)


root.mainloop()
